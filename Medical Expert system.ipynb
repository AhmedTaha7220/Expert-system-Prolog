# %%
# Out:
# ''

# %%
# Libraries and modes
import customtkinter as ctk
import tkinter as tk
from tkinter import ttk
import time
import random as rnd
from PIL import Image, ImageTk
ctk.set_appearance_mode("dark")
ctk.set_default_color_theme("blue")
root=ctk.CTk()
################################################################

# Coordinates of the frame
width = 1900
length = 1080
space = 100
ts = 10 # text size

root.geometry(f"{width}x{length}")

root.title("Medical Expert System")

# Our frames
Main = ctk.CTkFrame(master=root, width=width, height=length)

Patient = ctk.CTkFrame(root,width=width,height=length)
Patient1 = ctk.CTkFrame(root,width=width,height=length)
Patient2 = ctk.CTkFrame(root,width=width,height=length)
Patient3 = ctk.CTkFrame(root,width=width,height=length)
Patient_result = ctk.CTkFrame (root,width=width,height=length)

Doctor = ctk.CTkFrame(root,width=width,height=length)
Doctor1 = ctk.CTkFrame(root,width=width,height=length)
Doctor2 = ctk.CTkFrame(root,width=width,height=length)
################################################################
## MAIN FRAME:
####################
Main.pack()
## Background Main image
imgg = Image.open(
    r"D:\0.In progress\2.lectures\0.Graduation project\Guardian on chip\3.Medical Expert system\main.png"
)
backimg = imgg.resize((int(width/2-200), length-10), Image.LANCZOS)
img = ImageTk.PhotoImage(backimg)
imge = ctk.CTkLabel(master=Main, image=img, text=" ")
imge.place(x=width/2-300,y=0)

lbl1 = ctk.CTkLabel(master=Main, text="Medical Expert System", font=("Times New roman",ts*7),text_color="#6da1d4")
lbl1.place(x=width/2-250,y=10)

def patient():
    Main.pack_forget()
    Patient.pack()
btn1 = ctk.CTkButton(master=Main, text="Patient Mode", font=("Arial",ts*5),command=patient)
btn1.place(x=width/2-70,y=int(length-400))

def doctor():
    Main.pack_forget()
    Doctor.pack()
btn2 = ctk.CTkButton(master=Main, text="Doctor Mode", font=("Arial",ts*5),command=doctor)
btn2.place(x=width/2-70,y=int(length-250))

################################################################
## Patient Frame:
####################
## Background Patient image
imgg = Image.open(
    r"D:\0.In progress\2.lectures\0.Graduation project\Guardian on chip\3.Medical Expert system\patient.png"
)
backimg = imgg.resize((int(width/2+300), 1100), Image.LANCZOS)
img = ImageTk.PhotoImage(backimg)
imge_patient = ctk.CTkLabel(master=Patient, image=img, text=" ")
imge_patient.place(x=400,y=0)

patient_title1=ctk.CTkLabel(Patient,text="Patient Window",font=("Arial",ts*5),text_color="#25C8EC")
patient_title1.place(x=width/2-220,y=30)

namee = ctk.CTkLabel(Patient, text="Name:", font=("Arial", ts*3), text_color="#6da1d4")
namee.place(x=10, y=30+space)
namee_entry = ctk.CTkEntry(Patient, font=("Arial", ts*3), width=300)
namee_entry.place(x=width/2, y=30+space)

agee = ctk.CTkLabel(Patient, text="Age:", font=("Arial", ts*3), text_color="#6da1d4")
agee.place(x=10, y=30+space*2)
age = ctk.StringVar()
agee_entry = ctk.CTkEntry(Patient, font=("Arial", ts*3), width=100, textvariable=age)
agee_entry.insert(0,"00")
agee_entry.place(x=width/2, y=30+space*2)

Genderr = ctk.CTkLabel(Patient, text="Gender:", font=("Arial", ts*3), text_color="#6da1d4")
Genderr.place(x=10, y=30+space*3)
Gender = ["male", "female"]
c_combo1=ctk.CTkComboBox(Patient,values=Gender,font=("Arial",ts*3))
c_combo1.place(x=width/2, y=30+space*3)
# genderr.place(x=100, y=310)

weightt = ctk.CTkLabel(Patient, text="Weight 'in Kg':", font=("Arial", ts*3), text_color="#6da1d4")
weightt.place(x=10, y=30+space*4)
weight=ctk.StringVar()
weightt_entry = ctk.CTkEntry(Patient, font=("Arial", ts*3), width=100, textvariable=weight)
weightt_entry.insert(0,"00 Kg")
weightt_entry.place(x=width/2, y=30+space*4)

heightt = ctk.CTkLabel(Patient, text="Height 'in Cm':", font=("Arial", ts*3), text_color="#6da1d4")
heightt.place(x=10, y=30+space*5)
height=ctk.StringVar()
heightt_entry = ctk.CTkEntry(Patient, font=("Arial", ts*3), width=100,textvariable=height)
heightt_entry.insert(0,"00 Cm")
heightt_entry.place(x=width/2, y=30+space*5)

def patient1():
    Patient.pack_forget()
    Patient1.pack()
go_p1_btn = ctk.CTkButton(master=Patient,text="Next", font=("Arial",ts*5),command=patient1)
go_p1_btn.place(x=width/2+200,y=30+space*6)
################################################################
## Patient1 Frame:
####################
p1_lbl = ctk.CTkLabel(Patient1,text="(Symptoms Group 1: If you have any of these symptoms check on it:",font=("Arial",ts*5),text_color="#25C8EC")
p1_lbl.place(x=10,y=30)

p1_check1 = ctk.CTkCheckBox(Patient1,text="Fractures in the hip, spine, or wrist.",font=("Arial",ts*3))
p1_check1.place(x=10, y=30+space*2)

p1_check2 = ctk.CTkCheckBox(Patient1,text="Back Pain.",font=("Arial",ts*3))
p1_check2.place(x=10, y=30+space*3)

p1_check3 = ctk.CTkCheckBox(Patient1,text="Stooped Posture.",font=("Arial",ts*3))
p1_check3.place(x=10, y=30+space*4)

p1_check4 = ctk.CTkCheckBox(Patient1,text="Loss of height over time.",font=("Arial",ts*3))
p1_check4.place(x=10, y=30+space*5)

def patient2():
    Patient1.pack_forget()
    Patient2.pack()
go_p2_btn = ctk.CTkButton(master=Patient1,text="Next", font=("Arial",ts*5),command=patient2)
go_p2_btn.place(x=width/2+200,y=30+space*6)
################################################################
## Patient2 Frame:
####################
p2_lbl = ctk.CTkLabel(Patient2,text="(Symptoms Group 2: If you have any of these symptoms check on it:",font=("Arial",ts*5),text_color="#25C8EC")
p2_lbl.place(x=10,y=30)

p2_check1 = ctk.CTkCheckBox(Patient2,text="Fatigue or feeling unusually tired..",font=("Arial",ts*3))
p2_check1.place(x=10, y=30+space*2)

p2_check2 = ctk.CTkCheckBox(Patient2,text="Fever or Low-grade fever..",font=("Arial",ts*3))
p2_check2.place(x=10, y=30+space*3)

p2_check3 = ctk.CTkCheckBox(Patient2,text="Unintentional weight loss.",font=("Arial",ts*3))
p2_check3.place(x=10, y=30+space*4)

p2_check4 = ctk.CTkCheckBox(Patient2,text="Firm lumps under the skin, typically around pressure points.",font=("Arial",ts*3))
p2_check4.place(x=10, y=30+space*5)

p2_check5 = ctk.CTkCheckBox(Patient2,text="Swelling around the affected joints, which can feel warm to the touch.",font=("Arial",ts*3))
p2_check5.place(x=10, y=30+space*6) 

p2_check6 = ctk.CTkCheckBox(Patient2,text="Joint stiffness, particularly in the morning or after periods of inactivity, lasting for more than 30 minutes",font=("Arial",ts*3))
p2_check6.place(x=10, y=30+space*7)
def patient3():
    Patient2.pack_forget()
    Patient3.pack()
go_p3_btn = ctk.CTkButton(master=Patient2,text="Next", font=("Arial",ts*5),command=patient3)
go_p3_btn.place(x=width/2+200,y=30+space*6)
################################################################
## Patient3 Frame:
###################
p3_lbl = ctk.CTkLabel(Patient3,text="(Symptoms Group 3: If you have any of these symptoms check on it:",font=("Arial",ts*5),text_color="#25C8EC")
p3_lbl.place(x=10,y=30)

global var
var = 0
v = ctk.IntVar()
def get_val():
    global var
    var=v.get()
p3_check1 = ctk.CTkCheckBox(Patient3,text="Uneven Shoulders One shoulder may be higher than the other.",variable=v, font=("Arial",ts*3), command=get_val)
p3_check1.place(x=10, y=30+space*2)

p3_check2 = ctk.CTkCheckBox(Patient3,text="One hip may be higher or more prominent than the other.",font=("Arial",ts*3))
p3_check2.place(x=10, y=30+space*3)

p3_check3 = ctk.CTkCheckBox(Patient3,text="Limited Range of Motion: Difficulty with certain movements due to stiffness or discomfort in the spine.",font=("Arial",ts*3))
p3_check3.place(x=10, y=30+space*4)

p3_check4 = ctk.CTkCheckBox(Patient3,text="Leg Length Discrepancy: One leg may appear longer than the other.",font=("Arial",ts*3))
p3_check4.place(x=10, y=30+space*5)

p3_check5 = ctk.CTkCheckBox(Patient3,text="Breathing Issues: If the curve is significant, it can affect lung capacity and breathing.",font=("Arial",ts*3))
p3_check5.place(x=10, y=30+space*6) 


def final_out():
    # Create a progress bar
    progressbar = ttk.Progressbar(master=Patient3, orient="horizontal", length=700, mode="determinate")
    progressbar.place(x=width/2-300,y=30+space*7)

    # Define the function to start the progress
    def start_progress():
        progressbar["value"] = 0
        max_value = 100
        progressbar["maximum"] = max_value

        for i in range(max_value + 1):
            time.sleep(0.05)
            progressbar["value"] = i
            root.update_idletasks()
    start_progress()
    Patient3.pack_forget()
    Patient_result.pack()
    if var == 0:
        p_out_lbl1 = ctk.CTkLabel(Patient_result,text="Nothing, You are okay, you just need some rest😊",font=("Arial",ts*3))
        p_out_lbl1.place(x=10,y=30+space*2)
        def goHome():
            p_out_lbl1.configure(text=" ")
            Patient_result.pack_forget()
            Main.pack()
        p_out_goHome = ctk.CTkButton(master=Patient_result, text="Return to Home", font=("Arial",ts*4),command=goHome)
        p_out_goHome.place(x=width/2-250,y=length-200)
    else:
        # Diseases printing
        dis_list = rnd.sample(diseas,d)
        my_string1 = '\n'.join(dis_list)
        p_out_lbl1 = ctk.CTkLabel(master=Patient_result,text=f"{my_string1}",font=("Arial",ts*3))
        p_out_lbl1.place(x=10,y=30+space*2)
        # Causes printing
        cas_list = rnd.sample(cause,c)
        my_string2 = '\n'.join(cas_list)
        p_out_lbl2 = ctk.CTkLabel(Patient_result,text=f"{my_string2}", font=("Arial",ts*3))
        p_out_lbl2.place(x=10,y=30+space*5)
        # Severity priting
        sever_list = rnd.sample(severity,1)
        my_string3 = '\n'.join(sever_list)
        p_out_lbl3 = ctk.CTkLabel(Patient_result,text=f"{my_string3}", font=("Arial",ts*3))
        p_out_lbl3.place(x=width/2+200,y=30+space*2)
        # Treatment Medication
        med_list = rnd.sample(treat_med,med)
        my_string4 = '\n'.join(med_list)
        p_out_lbl4 = ctk.CTkLabel(Patient_result,text=f"{my_string4}", font=("Arial",ts*3))
        p_out_lbl4.place(x=width/2,y=30+space*6)
        # Treatment life style
        life_list = rnd.sample(treat_life,life)
        my_string5 = '\n'.join(life_list)
        p_out_lbl5 = ctk.CTkLabel(Patient_result,text=f"{my_string5}", font=("Arial",ts*3))
        p_out_lbl5.place(x=width/2+500,y=30+space*6)
        
        def goHome():
            p_out_lbl1.configure(text=" ")
            p_out_lbl2.configure(text=" ")
            p_out_lbl3.configure(text=" ")
            p_out_lbl4.configure(text=" ")
            p_out_lbl5.configure(text=" ")
            Patient_result.pack_forget()
            Main.pack()
        p_out_goHome = ctk.CTkButton(master=Patient_result, text="Return to Home", font=("Arial",ts*4),command=goHome)
        p_out_goHome.place(x=width/2-250,y=length-200)

go_p3_btn = ctk.CTkButton(master=Patient3,text="Next", font=("Arial",ts*5),command=final_out)
go_p3_btn.place(x=width/2+200,y=30+space*6)
################################################################
## Patient_result Frame:
####################
# List of Diseases
diseas = ["👉 osteoporosis", "👉 rheumatoid arthritis", "👉 Paget's disease of bone", "👉 osteogenesis imperfecta", "👉 Gout", "👉 scoliosis"]
d = rnd.randint(1,2)
# List of causes
cause = ["👉 Immune System Dysfunction","👉 Genetic Factors","👉 Environmental Triggers: Infections or physical trauma","👉 Bone Remodeling","👉 Nutritional Deficiencies"]
c = rnd.randint(3,5)
# List of severity
severity = ["👉 Normal","👉 Severe","👉 Moderate","👉 Mild"]

# List of Medication
treat_med = ["👉 NSAIDs: Ibuprofen, Naproxen", "👉 Corticosteroids: Prednisone.", "👉 Methotrexate, Leflunomide.", "👉 TNF inhibitors", "👉 Alendronate", "👉 Risedronate", "👉 Zoledronic acid"]
med = rnd.randint(3,5)
# List of life style
treat_life = ["👉 Exercise", "👉 Anti-inflammatory diet", "👉 Physical Therapy","👉 Improve joint flexibility","👉 Braces and Orthopedic Devices:"]
life = rnd.randint(2,3)
#######################################

p_out_titl = ctk.CTkLabel(master=Patient_result, text="Results Board", font=("Times New roman",ts*7),text_color="#6da1d4")
p_out_titl.place(x=width/2-220,y=30)

p_out_disease = ctk.CTkLabel(master=Patient_result, text="Diseases", font=("Arial",ts*5),text_color="#89C2FA")
p_out_disease.place(x=10,y=30+space)
    
p_out_cause = ctk.CTkLabel(master=Patient_result, text="Causes", font=("Arial",ts*5),text_color="#89C2FA")
p_out_cause.place(x=10,y=30+space*4)

p_out_severity = ctk.CTkLabel(master=Patient_result, text="Severity", font=("Arial",ts*5),text_color="#89C2FA")
p_out_severity.place(x=width/2+200,y=30+space)

p_out_Treat = ctk.CTkLabel(master=Patient_result, text="Suggested Treatments", font=("Arial",ts*5),text_color="#89C2FA")
p_out_Treat.place(x=width/2+200,y=30+space*4)
p_out_Medic = ctk.CTkLabel(master=Patient_result, text="Medications:", font=("Arial",ts*5),text_color="#89C2FA")
p_out_Medic.place(x=width/2,y=30+space*5)

p_out_life = ctk.CTkLabel(master=Patient_result, text="Life Style:", font=("Arial",ts*5),text_color="#89C2FA")
p_out_life.place(x=width/2+600,y=30+space*5)

################################################################
## Doctor Frame:
####################
## Background doctor image
imgg = Image.open(
    r"D:\0.In progress\2.lectures\0.Graduation project\Guardian on chip\3.Medical Expert system\doctor.png"
)
# backimg=imgg
backimg = imgg.resize((900, 1000), Image.LANCZOS)
img = ImageTk.PhotoImage(backimg)
imge = ctk.CTkLabel(master=Doctor, image=img, text=" ")
imge.place(x=0,y=0)

doc_titl = ctk.CTkLabel(master=Doctor, text="Doctor's Mode", font=("Times New roman",ts*7),text_color="#6da1d4")
doc_titl.place(x=width/2-200,y=30)

def goDoc1():
    Doctor.pack_forget()
    Doctor1.pack()
doc_btn1 = ctk.CTkButton(master=Doctor, text="Add New Disease", font=("Arial",ts*5),command=goDoc1)
doc_btn1.place(x=width/2-220,y=30+space*3)

doc_lbl1 = ctk.CTkLabel(Doctor, text="Choose the disease", font=("Arial",ts*2))
doc_lbl1.place(x=width/2+400,y=30+space*4)
# Combo Hanlding
comb1_choice = ctk.StringVar()
global comb1
comb1 = "initial"
def comb1_stor(c):
    global comb1
    comb1=c
doc_combo1=ctk.CTkComboBox(Doctor,values=diseas,variable=comb1_choice,command=comb1_stor,font=("Arial",ts*3),width=300)
doc_combo1.place(x=width/2+400, y=30+space*5)
##
def goDoc2():
    Doctor.pack_forget()
    Doctor2.pack()
    doc2_titl.configure(text=f"Modify Disease {comb1}")
    doc2_entry1.insert(0,comb1)
    doc2_entry2.insert("1.0",f"👉 Severe Joint Pain\n👉 Sudden Onset of Pain\n👉 Swelling and Redness\n👉 Lingering Discomfort\n👉 Tophi Formatio\n👉 Limited Range of Motion")
    doc2_entry3.insert("1.0",f"👉 Immune System Dysfunction\n👉 Genetic Factors\n👉 Environmental Triggers: Infections or physical trauma\nBone Remodeling\n👉 Nutritional Deficiencies\n👉 Sugary Drinks")
    doc2_entry4.insert("1.0",f"👉 Age & Gender\n👉 Family history of diseases\n👉 Diabetes\n👉 Metabolic Syndrome\n👉 Hypertension (High Blood Pressure)\n👉 ObesityHigh-Purine Foods\n👉 Alcohol\n👉 Sugary Beverages")
    doc2_entry5.insert("1","Moderate")
    doc2_entry6.insert("1.0",f"👉 Anti-Inflammatory Medications (Nonsteroidal Anti-Inflammatory Drugs (NSAIDs) - Corticosteroids - Colchicine)\n👉 Reduce Uric Acid Levels (Xanthine Oxidase Inhibitors - Uricosurics)\n👉 Pegloticase (Krystexxa)")
    doc2_entry7.insert("1.0",f"👉 Avoid Sugary Drinks\n👉 Avoid Alchohol\n👉 Increase Low-Fat Dairy\n👉 Eat More Plant-Based Foods\n👉 Stay Hydrated\n👉 Exercise Regularly\n👉 Manage Stress\n👉 Maintain a Healthy Weight")
doc_btn2 = ctk.CTkButton(master=Doctor, text="Modify Current Disease", font=("Arial",ts*5),command=goDoc2)
doc_btn2.place(x=width/2-240,y=30+space*5)

doc_lbl2 = ctk.CTkLabel(Doctor, text="Choose the disease", font=("Arial",ts*2))
doc_lbl2.place(x=width/2+400,y=30+space*6)
# Combo handling
comb2_choice=ctk.StringVar()
global comb2
comb2 = "initial"
def comb2_stor(c):
    global comb2
    comb2=c
doc_combo2=ctk.CTkComboBox(Doctor,values=diseas,variable=comb2_choice,command=comb2_stor,font=("Arial",ts*3),width=300)
doc_combo2.place(x=width/2+400, y=30+space*7)
##
def delt():
    doc_lbl3=ctk.CTkLabel(Doctor, text=f"Disease {comb2} is Deleted Successfully👍",font=("Arial",ts*4),text_color="green")
    doc_lbl3.place(x=width/2, y=30+space*8)
doc_btn1 = ctk.CTkButton(master=Doctor, text="Delete Disease", font=("Arial",ts*5),command=delt)
doc_btn1.place(x=width/2-220,y=30+space*7)
################################################################
## Doctor1 Frame:
####################
doc1_titl = ctk.CTkLabel(master=Doctor1, text="Add New Disease", font=("Times New roman",ts*7),text_color="#6da1d4")
doc1_titl.place(x=width/2-200,y=30)

doc1_lbl1 = ctk.CTkLabel(Doctor1,text="Disease Name:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl1.place(x=30, y=30+space*2)
doc1_entry1 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=200)
doc1_entry1.place(x=500,y=30+space*2)

doc1_lbl2 = ctk.CTkLabel(Doctor1,text="Symptoms:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl2.place(x=30, y=30+space*3)
doc1_entry2 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=300,height=200)
doc1_entry2.place(x=500,y=30+space*3)

doc1_lbl3 = ctk.CTkLabel(Doctor1,text="Causes:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl3.place(x=30, y=50+space*5)
doc1_entry3 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=300,height=200)
doc1_entry3.place(x=500,y=50+space*5)

doc1_lbl4 = ctk.CTkLabel(Doctor1,text="Risk Factors:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl4.place(x=30, y=70+space*7)
doc1_entry4 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=300,height=200)
doc1_entry4.place(x=500,y=70+space*7)

doc1_lbl5 = ctk.CTkLabel(Doctor1,text="Severity:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl5.place(x=850, y=30+space*2)
doc1_entry5 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=200)
doc1_entry5.place(x=1300,y=30+space*2)

doc1_lbl6 = ctk.CTkLabel(Doctor1,text="Suggested Medication:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl6.place(x=850, y=30+space*3)
doc1_entry6 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=300,height=200)
doc1_entry6.place(x=1300,y=30+space*3)

doc1_lbl7 = ctk.CTkLabel(Doctor1,text="Suggested Life Style:", font=("Arial",ts*4),text_color="#25C8EC")
doc1_lbl7.place(x=850, y=50+space*5)
doc1_entry7 = ctk.CTkEntry(Doctor1,font=("Arial",ts*3),width=300,height=200)
doc1_entry7.place(x=1300,y=50+space*5)

def disp():
    doc1_lbl8 = ctk.CTkLabel(Doctor1, text="Disease Added Successfully 👍", font=("Arial",ts*3),text_color="green")
    doc1_lbl8.place(x=1300,y=70+space*7)
doc1_btn1 = ctk.CTkButton(Doctor1, text="ADD",font=("Arial",ts*3),command=disp)
doc1_btn1.place(x=850,y=70+space*7)

def goMain():
    Doctor1.pack_forget()
    Main.pack()
doc1_btn2 = ctk.CTkButton(Doctor1, text="Go To Main",font=("Arial",ts*3),command=goMain)
doc1_btn2.place(x=850,y=70+space*8)
################################################################
## Doctor2 Frame:
####################
doc2_titl = ctk.CTkLabel(master=Doctor2, text=f"Modify Disease", font=("Times New roman",ts*7),text_color="#6da1d4")
doc2_titl.place(x=width/2-200,y=30)

doc2_lbl1 = ctk.CTkLabel(Doctor2,text="Disease Name:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl1.place(x=30, y=30+space*2)
doc2_entry1 = ctk.CTkEntry(Doctor2,font=("Arial",ts*3),width=200)
doc2_entry1.place(x=500,y=30+space*2)

doc2_lbl2 = ctk.CTkLabel(Doctor2,text="Symptoms:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl2.place(x=30, y=30+space*3)
doc2_entry2 = ctk.CTkTextbox(Doctor2,font=("Arial",ts*2),width=300,height=200)
doc2_entry2.place(x=500,y=30+space*3)

doc2_lbl3 = ctk.CTkLabel(Doctor2,text="Causes:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl3.place(x=30, y=50+space*5)
doc2_entry3 = ctk.CTkTextbox(Doctor2,font=("Arial",ts*2),width=300,height=200)
doc2_entry3.place(x=500,y=50+space*5)

doc2_lbl4 = ctk.CTkLabel(Doctor2,text="Risk Factors:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl4.place(x=30, y=70+space*7)
doc2_entry4 = ctk.CTkTextbox(Doctor2,font=("Arial",ts*2),width=300,height=200)
doc2_entry4.place(x=500,y=70+space*7)

doc2_lbl5 = ctk.CTkLabel(Doctor2,text="Severity:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl5.place(x=850, y=30+space*2)
doc2_entry5 = ctk.CTkEntry(Doctor2,font=("Arial",ts*3),width=200)
doc2_entry5.place(x=1300,y=30+space*2)

doc2_lbl6 = ctk.CTkLabel(Doctor2,text="Suggested Medication:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl6.place(x=850, y=30+space*3)
doc2_entry6 = ctk.CTkTextbox(Doctor2,font=("Arial",ts*2),width=300,height=200)
doc2_entry6.place(x=1300,y=30+space*3)

doc2_lbl7 = ctk.CTkLabel(Doctor2,text="Suggested Life Style:", font=("Arial",ts*4),text_color="#25C8EC")
doc2_lbl7.place(x=850, y=50+space*5)
doc2_entry7 = ctk.CTkTextbox(Doctor2,font=("Arial",ts*2),width=300,height=200)
doc2_entry7.place(x=1300,y=50+space*5)

def disp():
    doc2_lbl8 = ctk.CTkLabel(Doctor2, text="Disease Modified Successfully 👍", font=("Arial",ts*3),text_color="green")
    doc2_lbl8.place(x=1300,y=70+space*7)
doc2_btn1 = ctk.CTkButton(Doctor2, text="Modfiy",font=("Arial",ts*3),command=disp)
doc2_btn1.place(x=850,y=70+space*7)

def goMain():
    Doctor2.pack_forget()
    Main.pack()
doc2_btn2 = ctk.CTkButton(Doctor2, text="Go To Main",font=("Arial",ts*3),command=goMain)
doc2_btn2.place(x=850,y=70+space*8)
root.mainloop()
# Out:
# c:\Users\Mega Store\AppData\Local\Programs\Python\Python310\lib\site-packages\customtkinter\windows\widgets\core_widget_classes\ctk_base_class.py:179: UserWarning: CTkLabel Warning: Given image is not CTkImage but <class 'PIL.ImageTk.PhotoImage'>. Image can not be scaled on HighDPI displays, use CTkImage instead.
#
#   warnings.warn(f"{type(self).__name__} Warning: Given image is not CTkImage but {type(image)}. Image can not be scaled on HighDPI displays, use CTkImage instead.\n")
